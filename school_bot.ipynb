# %% [markdown]
# <a href="https://colab.research.google.com/github/Gail529/Automated-Essay--Scoring/blob/master/school_bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rasa==1.10.3
# Out:
# ...
#      |████████████████████████████████| 512kB 8.6MB/s
# ...
#      |████████████████████████████████| 51kB 5.6MB/s
# ...
#      |████████████████████████████████| 81kB 7.5MB/s
# ...
#      |████████████████████████████████| 81kB 7.5MB/s
# ...
#      |████████████████████████████████| 419kB 14.3MB/s
# ...
#      |████████████████████████████████| 450kB 25.0MB/s
# ...
#      |████████████████████████████████| 40kB 4.8MB/s
# ...
#      |████████████████████████████████| 102kB 7.3MB/s
# ...
#      |████████████████████████████████| 112kB 23.5MB/s
# ...
#      |████████████████████████████████| 61kB 6.7MB/s
# ...
#      |████████████████████████████████| 993kB 23.7MB/s
# ...
#      |████████████████████████████████| 102kB 9.8MB/s
# ...
#      |████████████████████████████████| 153kB 35.5MB/s
# ...
#      |████████████████████████████████| 983kB 43.9MB/s
# ...
#      |████████████████████████████████| 3.0MB 42.9MB/s
# ...
#      |████████████████████████████████| 348kB 45.9MB/s
# ...
#      |████████████████████████████████| 61kB 6.6MB/s
# ...

# %%
# !python -m spacy download en
# Out:
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
# !pip install nest_asyncio==1.3.3
# Out:
# ...
# ERROR: nbclient 0.5.3 has requirement jupyter-client>=6.1.5, but you'll have jupyter-client 5.3.5 which is incompatible.
# ...
#   Found existing installation: nest-asyncio 1.5.1
#     Uninstalling nest-asyncio-1.5.1:
#       Successfully uninstalled nest-asyncio-1.5.1
# ...

# %%
import os
import rasa
import nest_asyncio

nest_asyncio.apply()
print("Event loop ready.")
# Out:
# Event loop ready.

# %%
from rasa.cli.scaffold import create_initial_project
project = "school-bot"
create_initial_project(project)

# %%
#move into project directory and show files
os.chdir(project)
print(os.listdir("."))
# Out:
# ['config.yml', 'credentials.yml', 'actions.py', 'domain.yml', '__init__.py', 'data', '__pycache__', 'tests', 'endpoints.yml']

# %%
from rasa.jupyter import chat

endpoints = 'endpoints.yml'

chat(model_path, endpoints)
# Out:
# Your bot is ready to talk! Type your messages here or send '/stop'.
# hey Bot
# I am a bot, powered by Rasa.
# how was your day
# Bye
# gooosh your not smart
# Here is something to cheer you up:
# <img src="https://i.imgur.com/nGF1K8f.jpg"/>
# Did that help you?
# nope
# Bye
# kk
# Bye
# /stop

# %%
# %%writefile data/nlu.md
#
# ## intent:greeting
# -Hi
# -How are you
# -Is anyone there?
# -Hello
# -Good day
# -Whats up
# -Hey there
#
#
# ## intent:intro
# -Whats your name
# -Who are you
# -Who am i talking to
# -What do you do
# -What can you do for me
#
# ## intent:semester_dates
# -When is the new semester starting
# -Official Starting date
# -semester DataBases
# -When are we opening
# -When does school start
# -School term dates
# -When do classes start
#
#
# ## intent:positive
# -yes
# -yeah
# -yep
# -Thank you
# -Ok
# -Okay, fine
# -Yes I understand
# -Yes Thank you
# -I see
# -thats nice
#
#
#
# ## intent:negative
# -no
# -not at all
# -Nope
# -Nooooooo
# -Thanks for nothing
# -Hell no
# -you are dumb
# -you are Foolish
# -you are stupid
# -you aregood for nothing
# -you are useless
# -you are beyond stupid
#
#
# ## intent:new_admission
# -Admission procedure for the school
# -procedure for being admitted
# -proceduure for taking admission
# -what is the official way for getting an admission
# -how does one get admitted
# -what is the official way of getting admmitted
# -What is the method for getting admission
# -what is the procedure for pursuing admission
#
#
# ## intent:affirm
# -Did that help
# -Is that what you needed
# -Is that Okay
# -Is that what you had asked for
#
#
# ## intent:goodbye
# -cya
# -See you later
# -Goodbye
# -I am Leaving
# -Have a Good day
# -Okay bye
# -Okay
# -k
#
#
# ## intent:courses_available
# -What courses do you offer
# -Courses on offer
# -Courses being offered
# -Which course Programmes do you offer
# -Which courses are currently available
#
# ## intent:entrance_qualification
# -what is the eligibility  criteria of the course
# -what is the acceptability criteria of the sourse
# -what are the qualification requirements to join the course
# -what academic requirements are needed to join the course
# -what is the qualification standard for joining the course
#
# ##  intent:entrance_Test
# -Is there any   entrance Test
# -Do you provide any entrance Test
# -Do you require an syllabus_entrance Test
# -Can I get the entrance test
# -Do you require a interview test
# -Am I expected to seat for an entrance test
#
# ## intent:age
# -how old
# -how old?
# -what is your age
# -how old are you
# -age?
#
# ## intent:name
# -what is your name
# -what should I call you
# -whats your name?
# -Do you have a name?
#
# ## intent:hours
# -when are you guys open
# -what are your hours
# -hours of operation
# -Earliest hour of operation
# -Latest hour of operation
# -When do you open
# -When do you close
#
# ## intent:Fees
# -What are the fees for Computer Science
# -Fees for computer Science per month
# -Fee
# -Overrall Fee
# -How much for school fees
#
# ## intent:abc
# -I want to learn  Ecommerce
# -I want to learn  Social Entrepreneurship
# -I want to learn  Communication
# -I want to learn  Management
# -I want to learn  Sales
# -I want to learn  Strategy
# -I want to learn  Operations
# -I want to learn  Project Management
# -I want to learn  Business Law
#
# ## intent:Web Development
# -I want to learn Web Development
# -Web Development
# -learn Web Development-
# -understand  Web Development-
#
# ## intent:Mobile Development
# -I want to learn  Mobile Development
# -Mobile Development-
# -learn Mobile Development
# -understand  Mobile Development-
#
# ## intent:iOS Development
# -I want to learn iOS Development
# -iOS Development
# -learn iOS Development-
# -understand  iOS Development-
#
# ## intent:Android Development
# -I want to learn Android Development
# -Android Development-
# -learn Android Development
# -understand  Android Development-
#
# ## intent:Programming
# -I want to learn Programming
# -Programming
# -learn Programming-
# -understand  Programming-
#
# ## intent:Game Development
# -I want to learn Game Development
# -Game Development-
# -learn Game Development
# -understand  Game Development-
#
# ## intent:Databases
# -I want to learn Databases
# -Databases
# -learn Databases-
# -understand  Databases-
#
# ## intent:Big Data
# -I want to learn Big Data
# -Big Data
# -learn Big Data
# -understand  Big Data-
# Out:
# Overwriting data/nlu.md

# %%
# %%writefile data/stories.md
#
# ## path 1
# * greeting
#     -utter_greeting
# * intro
#     -utter_name
# * new_admission
#     -utter_admission
#     -utter_affirm
# * positive
# * goodbye
#     -utter_goodbye
#
# ## path 2
# * greeting
#     -utter_greeting
# * intro
#     -utter_name
# * entrance_qualifications
#     -utter_entrance_qualifications
#     -utter_affirm
# * positive
# * goodbye
#     -utter_goodbye
#
#
# ## path 3
# * greeting
#     -utter_greeting
# * intro
#     -utter_name
# * entrance_test
#     -utter_entrance_test
#     -utter_affirm
# * positive
# * goodbye
#     -utter_goodbye
#
#
#  ## path 4
# * greeting
#     -utter_greeting
# * intro
#     -utter_name
# * new_admission
#     -utter_admission
#     -utter_affirm
# * positive
# * goodbye
#     -utter_goodbye
#
#
# ## path 5
# * greeting
#     -utter_greeting
# * intro
#     -utter_name
# * hours
#     -utter_hours
#    -utter_affirm
# * positive
# * goodbye
#     -utter_goodbye
#
#
# ## path 6
# * greeting
#     -utter_greeting
# * intro
#     -utter_name
# * fees
#     -utter_Fees
#     -utter_affirm
# * positive
# * goodbye
#     -utter_goodbye
#
#
# ## path 7
# *  greeting
#     -utter_greeting
# *  intro
#     -utter_name
# *  abc
#     -utter_abc
#     -utter_affirm
# * positive
# * goodbye
#     -utter_goodbye
#
# # path 8
# *  greeting
#     -utter_greeting
# *  intro
#     -utter_name
# *  courses_available
#     -utter_courses_available
# *  Web Development
#     -utter_Web Development
#     -utter_affirm
# * positive
# * goodbye
#     -utter_goodbye
#
#
#
# ## path 9
# *  greeting
#     -utter_greeting
# *  intro
#     -utter_name
# *  courses_available
#     -utter_courses_available
# *  Android Development
#     -utter_Android Development
#     -utter_affirm
# * positive
# * goodbye
#     -utter_goodbye
#
#
#
# ## path 10
# *  greeting
#     -utter_greeting
# *  intro
#     -utter_name
# *  courses_available
#     -utter_courses_available
# *  Game Development
#     -utter_Game Development
#     -utter_affirm
# * positive
# * goodbye
#     -utter_goodbye
#
#
# ## path 11
# *  greeting
#     -utter_greeting
# *  intro
#     -utter_name
# *  courses_available
#     -utter_courses_available
# *  Mobile Development
#     -utter_Mobile Development
#     -utter_affirm
# * positive
# * goodbye
#     -utter_goodbye
#
#
#
# ## path 13
# *  greeting
#     -utter_greeting
# *  intro
#     -utter_name
# *  courses_available
#     -utter_courses_available
# *  iOS Development
#     -utter_iOS Development
#     -utter_affirm
# * positive
# * goodbye
#     -utter_goodbye
#
#
# ## path 14
# *  greeting
#     -utter_greeting
# *  intro
#     -utter_name
# *  courses_available
#     -utter_courses_available
# * Programming
#     -utter_Programming
#     -utter_affirm
# * positive
# * goodbye
#     -utter_goodbye
#
#
#
# ## path 15
# *  greeting
#     -utter_greeting
# *  intro
#     -utter_name
# *  courses_available
#     -utter_courses_available
# *  Databases
#     -utter_Databases
#     -utter_affirm
# * positive
# * goodbye
#     -utter_goodbye
#
#
#
# ## path 17
# *  greeting
#     -utter_greeting
# *  intro
#     -utter_name
# *  courses_available
#     -utter_courses_available
# *  Big Data
#     -utter_Big Data
#     -utter_affirm
# *  utter_positive
# * goodbye
#     -utter_goodbye
# Out:
# Overwriting data/stories.md

# %%
 
 
 
  utter_Android Development:
  - text:"Here are the courses forAndroid Development 
        Getting started with Android Development
        Android Development 1
        Android Development 2
        Android Development for beginners"
 
  utter_Programming:
  - text:" We offer the following courses for Programming
        Programming For Everybody Getting Started With Python 
        Programming For Everybody Getting Started With JAVA 
        Programming For Everybody Getting Started With Javacript 
        Programming For Everybody Getting Started With C++ 
        Programming For Everybody Getting Started With C# 
        Programming For Everybody Getting Started With C 
        Introduction To Computer Programming"

  utter_Game Development:
  - text:"Here are the courses for Game Development
        Game Development For Modern Platforms
        Getting started with Game Development
        Game Development 1
        Game Development 2
        Game Development for beginners"
 
  utter_Databases:
  - text:"Here are the courses forDatabases
        Using Databases With SQL 
        Databases And Sql For Data Science
        RDBMS
        NoSQL"
 
    
  utter_Big Data:
  - text:"Here are the courses forBig Data
        Introduction To Big Data 
        Machine Learning With Big Data 
        Big Data Analysis With Scala And Spark 
        Big Data Modeling And Management Systems 
        Managing Big Data With Mysql 
        Graph Analytics For Big Data 
        Big Data Applications Machine Learning At Scale 
        Big Data Analysis Hive Spark Sql Dataframes And Graphframes 
        Cloud Computing Applications Part 2 Big Data And Applications In The Cloud 
        Big Data Essentials Hdfs Mapreduce And Spark Rdd 
        Big Data Applications Real Time Streaming 
        Google Cloud Platform Big Data And Machine Learning Fundamentals En Espa Ol 
        Google Cloud Platform Big Data And Machine Learning Fundamentals 
        Big Data Genes And Medicine 
        Security And Privacy For Big Data Part 2 
        Big Data Science With The Bd2k Lincs Data Coordination And Integration Center 
        Bioinformatics Capstone Big Data In Biology"


- utter_Web Development
  - utter_Mobile Development
  - utter_iOS Development
  - utter_Android Development
  - utter_Programming
  - utter_Game Development
  - utter_Databases 
  - utter_Big Data

# %%
# %%writefile domain.yml
#
#
# intents:
#   - greeting
#   - intro
#   - semester_dates
#   - positive
#   - negative
#   - new_admission
#   - goodbye
#   - courses_available
#   - entrance_qualifications
#   - entrance_test
#   - age
#   - name
#   - hours
#   - Fees
#   - abc
#   - Web Development
#   - Mobile Development
#   - iOS Development
#   - Android Development
#   - Programming
#   - Game Development
#   - Databases
#   - Big Data
#
#
#
# actions:
#   - utter_greeting
#   - utter_out_of_scope
#   - utter_positive
#   - utter_negative
#   - utter_admission
#   - utter_goodbye
#   - utter_affirm
#   - utter_courses_available
#   - utter_entrance_qualifications
#   - utter_entrance_test
#   - utter_age
#   - utter_name
#   - utter_hours
#   - utter_Fees
#   - utter_abc
#   - utter_Web Development
#   - utter_Mobile Development
#   - utter_iOS Development
#   - utter_Android Development
#   - utter_Programming
#   - utter_Game Development
#   - utter_Databases
#   - utter_Big Data
#
#
#
#
# templates:
#   utter_greeting:
#   - text:"Hi"
#   - text:"Hello!"
#   - text:"Hi Three"
#   - text:"Hi there, how can I help? "
#
#   utter_goodbye:
#   - text:"Sad to see you go :("
#   - text:"Goodbye! "
#   - text:"Goodbye ,have a nice Time "
#   - text:"Hope I was of help to you"
#
#   utter_semester_dates:
#   - text:"This coming semester starts on 4th January  You can find the official document that outlines the term dates plus the time table here."link"
#
#   utter_courses available:
#   - text:"We offer a wide range of Computer Science and Programming Courses .What do you want to learn ?"
#   - text:"We have courses ranging  from Basic Programming to Advanced specializations (including but not limited to)  Software Engineering, AI .What do you want to learn "
#
#   utter_age:
#   - text: "Good Question I dont age: "
#   - text: "I am a bot I dont  age,"
#   - text: "Haha ,I am immortal"
#
#
#   utter_name:
#   - text:"You can call me Gail. Here for any Admission or Course Enrollment inquiries.How may I help you?"
#   - text: "Im Gail, Here for any Admission or Course Enrollment inquiries.How may I help you?"
#   - text: "Gail, Here for any Admission or Course Enrollment inquiries.How may I help you?"
#   - text: "My name is Gail . Here for any Admission or Course Enrollment inquiries.How may I help you?"
#
#
#   utter_hours:
#   - text:"We are open 7am4pm MondayFriday!"
#   - text:"Anytime from 7am to 4pm "
#   - text:"Weekdays from 7am to 4pm"
#
#
#   utter_abc:
#   - text: "Sorry ,We only offer Computer Science related Courses "
#   - text: "Unfortunately ,We only offer CS and Programming Courses "
#   - text: "At the moment we only provide courses related to Information Technology"
#
#   utter_admission:
#   - text:"A detailed procedure for admission has been outlined in this page "
#
#   utter_entrance_qualification:
#   - text:"You only need a high school certificate to prove that you have the basic Math and Literacy Skills
#   - text:"Basic Math and Literacy Skills plus a high school certification that affirms the same
#
#   utter_entrance_test:
#   - text:"Nope we don't require entrance tests."
#
#   utter_affirm:
#   - text: "Does that answer your question??"
#   - text: "Was that helpful in anyway??"
#   - text: "Is the answer helpful??"
#   - text: "Hope my services were helpful??"
#   - text: "Were my services of any help??"
#
#   utter_disappoint:
#   - text:"Sorry ,I will try to learn from this experience "
#   - text:"I am sorry I wasn't as helpful as you expected.I will try to learn from this experience "
#   - text:"I will try to learn from this experience "
#
#   utter_Web Development:
#   - text:"Here are the courses forWeb Development
#         Getting started with Web Development
#         Web Development 1
#         Web Development 2
#         Web Development for beginners
#         Responsive Website Basics Code With Html Css And Javascript
#         Html Css And Javascript For Web Developers"
#
#
#   utter_Android Development:
#   - text:"Here are the courses forAndroid Development
#         Getting started with Android Development
#         Android Development 1
#         Android Development 2
#         Android Development for beginners"
#
#   utter_Programming:
#   - text:" We offer the following courses for Programming
#         Programming For Everybody Getting Started With Python
#         Programming For Everybody Getting Started With JAVA
#         Programming For Everybody Getting Started With Javacript
#         Programming For Everybody Getting Started With C++
#         Programming For Everybody Getting Started With C#
#         Programming For Everybody Getting Started With C
#         Introduction To Computer Programming"
#
#   utter_Game Development:
#   - text:"Here are the courses for Game Development
#         Game Development For Modern Platforms
#         Getting started with Game Development
#         Game Development 1
#         Game Development 2
#         Game Development for beginners"
#
#   utter_Databases:
#   - text:"Here are the courses forDatabases
#         Using Databases With SQL
#         Databases And Sql For Data Science
#         RDBMS
#         NoSQL"
#
#
#   utter_Big Data:
#   - text:"Here are the courses forBig Data
#         Introduction To Big Data
#         Machine Learning With Big Data
#         Big Data Analysis With Scala And Spark
#         Big Data Modeling And Management Systems
#         Managing Big Data With Mysql
#         Graph Analytics For Big Data
#         Big Data Applications Machine Learning At Scale
#         Big Data Analysis Hive Spark Sql Dataframes And Graphframes
#         Cloud Computing Applications Part 2 Big Data And Applications In The Cloud
#         Big Data Essentials Hdfs Mapreduce And Spark Rdd
#         Big Data Applications Real Time Streaming
#         Google Cloud Platform Big Data And Machine Learning Fundamentals En Espa Ol
#         Google Cloud Platform Big Data And Machine Learning Fundamentals
#         Big Data Genes And Medicine
#         Security And Privacy For Big Data Part 2
#         Big Data Science With The Bd2k Lincs Data Coordination And Integration Center
#         Bioinformatics Capstone Big Data In Biology"
# Out:
# Overwriting domain.yml

# %%
# %%writefile config.yml
#
# language: "en"
#
# pipeline:
# - name: "SpacyNLP"                   # loads the spacy language model
# - name: "SpacyTokenizer"
# - name: "SpacyFeaturizer"             # splits the sentence into tokens
# - name: "RegexFeaturizer"             # splits the sentence into tokens
# - name: "LexicalSyntacticFeaturizer"             # splits the sentence into tokens
# - name: "CountVectorsFeaturizer"
# - name: "DIETClassifier"   # uses the vector representation to classify using SVM
# - name: "EntitySynonymMapper"                # trains the synonyms
#
# policies:
# - name: MemoizationPolicy
# Out:
# Overwriting config.yml

# %%
config = "config.yml" 
training_files = "data/"
domain = "domain.yml"
output = "models/"
print(config, training_files, domain, output)
# Out:
# config.yml data/ domain.yml models/

# %%
model_path = rasa.train(domain, config, [training_files], output)
print(model_path)
# Out:
# Training Core model...
# ...
# Processed trackers: 100%|██████████| 14/14 [00:00<00:00, 58.58it/s, # actions=91]
# Processed actions: 91it [00:00, 346.94it/s, # examples=91]
# Core model training completed.
# Training NLU model...
# Epochs: 100%|██████████| 300/300 [01:55<00:00,  2.59it/s, t_loss=1.736, i_loss=0.801, i_acc=0.906]
# NLU model training completed.
# Your Rasa model is trained and saved at '/content/school-bot/models/20210326-051752.tar.gz'.
# models/20210326-051752.tar.gz

# %%
import warnings
warnings.filterwarnings("ignore")
from rasa.jupyter import chat

endpoints = 'endpoints.yml'

chat(model_path, endpoints)
# Out:
# Your bot is ready to talk! Type your messages here or send '/stop'.
# hello
# text:"Hi Three"
# Who are you
# Im Gail, Here for any Admission or Course Enrollment inquiries.How may I help you?
# How does one get admitted
# text:"A detailed procedure for admission has been outlined in this page "
# Is the answer helpful??
# yes
# What is the procedure for admission
# /stop

# %%
from rasa.jupyter import chat

endpoints = 'endpoints.yml'

chat(model_path, endpoints)
# Out:
# Your bot is ready to talk! Type your messages here or send '/stop'.
# hello
# text:"Hi there, how can I help? "
# Whats your name
# /top
# /stop
